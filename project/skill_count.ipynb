# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
import ast

# load dataset
dataset= load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# clean dataset
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_skills_count = df.copy()

# %%
df_skills_count_explode = df_skills_count.explode('job_skills')
df_skills_count_explode
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_counts = df_skills_count_explode.groupby(['job_title_short', 'job_skills']).size()
df_counts
# Out:
# job_title_short    job_skills
# Business Analyst   airflow        318
#                    airtable        17
#                    alteryx       1078
#                    angular         87
#                    ansible        120
#                                  ...
# Software Engineer  wrike            4
#                    wsl             13
#                    xamarin         35
#                    yarn           145
#                    zoom           229
# Length: 2256, dtype: int64

# %%
total_skill= df_counts.reset_index(name='total_skill_count')
total_skill
# Out:
#         job_title_short job_skills  total_skill_count
# 0      Business Analyst    airflow                318
# 1      Business Analyst   airtable                 17
# 2      Business Analyst    alteryx               1078
# 3      Business Analyst    angular                 87
# 4      Business Analyst    ansible                120
# ...                 ...        ...                ...
# 2251  Software Engineer      wrike                  4
# 2252  Software Engineer        wsl                 13
# 2253  Software Engineer    xamarin                 35
# 2254  Software Engineer       yarn                145
# 2255  Software Engineer       zoom                229
#
# [2256 rows x 3 columns]

# %%
total_skill = total_skill.sort_values(by='total_skill_count', ascending=False)
total_skill
# Out:
#             job_title_short   job_skills  total_skill_count
# 1066         Data Scientist       python             113711
# 865           Data Engineer          sql             113130
# 830           Data Engineer       python             108022
# 625            Data Analyst          sql              92428
# 1101         Data Scientist          sql              78982
# ...                     ...          ...                ...
# 266          Cloud Engineer       delphi                  1
# 1920  Senior Data Scientist  objective-c                  1
# 1400    Senior Data Analyst      couchdb                  1
# 298          Cloud Engineer      haskell                  1
# 631            Data Analyst         suse                  1
#
# [2256 rows x 3 columns]

# %%
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

fig,ax = plt.subplots(3,1)

for i, job_title in enumerate(job_titles):
    df_plot = total_skill[total_skill['job_title_short'] == job_title].head(5)
    df_plot.plot(kind='barh', x= 'job_skills',  ax=ax[i], title = job_title)
    ax[i].invert_yaxis()
    ax[i].set_ylabel('')
    ax[i].legend().set_visible(False)
    ax[i].set_xlim(0, 120000)
    fig.tight_layout()
    fig.suptitle('Counts of top skills in job posting', fontsize=17)
