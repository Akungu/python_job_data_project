# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
import ast

# load dataset
dataset= load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# clean dataset
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_data_analysis = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_data_analysis['month_number'] = df_data_analysis['job_posted_date'].dt.month
df_data_analysis
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_data_analysis_explode = df_data_analysis.explode('job_skills')
df_data_analysis_explode
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
df_data_analysis_explode_pivot = df_data_analysis_explode.pivot_table(
    index='month_number',
    columns='job_skills',
    aggfunc='size',
    fill_value=0
)

df_data_analysis_explode_pivot.loc['total'] = df_data_analysis_explode_pivot.sum()
df_data_analysis_explode_pivot = df_data_analysis_explode_pivot[df_data_analysis_explode_pivot.loc['total'].sort_values(ascending=False).index]

df_data_analysis_explode_pivot = df_data_analysis_explode_pivot.drop('total')
df_data_analysis_explode_pivot
# Out:
# job_skills      sql  excel  python  tableau  power bi     r   sas  powerpoint  \
# month_number
# 1             11336   8170    6606     5596      4285  3607  3830        1880
# 2              7947   5772    4751     3936      3307  2576  2634        1291
# 3              7868   5675    4741     4051      3176  2650  2554        1266
# 4              7553   5496    4557     3776      3106  2399  2598        1190
# 5              6617   4773    4070     3245      2695  2093  1940         979
# 6              7584   5724    4707     3812      3275  2442  2174        1173
# 7              7687   5513    4831     3928      3350  2444  2118        1096
# 8              8823   6482    5576     4533      3859  2975  2560        1332
# 9              6829   4886    4229     3446      3118  2146  1880         944
# 10             7474   5217    4693     3709      3340  2380  2114         955
# 11             6652   4776    4233     3284      3012  2159  1738         894
# ...

# %%
df_data_analysis_explode_pivot.iloc[:,:5].plot(kind='line')
# Out:
# <Axes: xlabel='month_number'>
